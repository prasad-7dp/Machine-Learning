# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
import pickle

# %%
data = pd.read_csv(r'C:\Users\admin\Desktop\tefoLOGIC\Data\rainfall_in_india_1901-2015.csv')
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data.shape
# Out:
# (4116, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4112 non-null   float64
#  3   FEB          4113 non-null   float64
#  4   MAR          4110 non-null   float64
#  5   APR          4112 non-null   float64
#  6   MAY          4113 non-null   float64
#  7   JUN          4111 non-null   float64
#  8   JUL          4109 non-null   float64
#  9   AUG          4112 non-null   float64
#  10  SEP          4110 non-null   float64
#  11  OCT          4109 non-null   float64
#  12  NOV          4105 non-null   float64
#  13  DEC          4106 non-null   float64
#  14  ANNUAL       4090 non-null   float64
#  15  Jan-Feb      4110 non-null   float64
#  16  Mar-May      4107 non-null   float64
#  17  Jun-Sep      4106 non-null   float64
# ...

# %%
data.describe().T
# Out:
#           count         mean         std     min       25%     50%       75%  \
# YEAR     4116.0  1958.218659   33.140898  1901.0  1930.000  1958.0  1987.000
# JAN      4112.0    18.957320   33.585371     0.0     0.600     6.0    22.200
# FEB      4113.0    21.805325   35.909488     0.0     0.600     6.7    26.800
# MAR      4110.0    27.359197   46.959424     0.0     1.000     7.8    31.300
# APR      4112.0    43.127432   67.831168     0.0     3.000    15.7    49.950
# MAY      4113.0    85.745417  123.234904     0.0     8.600    36.6    97.200
# JUN      4111.0   230.234444  234.710758     0.4    70.350   138.7   305.150
# JUL      4109.0   347.214334  269.539667     0.0   175.600   284.8   418.400
# AUG      4112.0   290.263497  188.770477     0.0   155.975   259.4   377.800
# SEP      4110.0   197.361922  135.408345     0.1   100.525   173.9   265.800
# OCT      4109.0    95.507009   99.519134     0.0    14.600    65.2   148.400
# ...

# %%
data.columns.tolist()
# Out:
# ['SUBDIVISION',
#  'YEAR',
#  'JAN',
#  'FEB',
#  'MAR',
#  'APR',
#  'MAY',
#  'JUN',
#  'JUL',
#  'AUG',
#  'SEP',
#  'OCT',
#  'NOV',
#  'DEC',
#  'ANNUAL',
#  'Jan-Feb',
#  'Mar-May',
#  'Jun-Sep',
#  'Oct-Dec']

# %%
data.isna().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data1 = data.drop(['Jan-Feb','Mar-May','Jun-Sep','Oct-Dec','ANNUAL'],axis=1)
data1.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC
# 0  365.1  481.1  332.6  388.5  558.2   33.6
# 1  228.9  753.7  666.2  197.2  359.0  160.5
# 2  728.4  326.7  339.0  181.2  284.4  225.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1
# 4  368.7  330.5  297.0  260.7   25.4  344.7

# %%
data1.isna().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# dtype: int64

# %%
data1.describe().T
# Out:
#        count         mean         std     min       25%     50%      75%  \
# YEAR  4116.0  1958.218659   33.140898  1901.0  1930.000  1958.0  1987.00
# JAN   4112.0    18.957320   33.585371     0.0     0.600     6.0    22.20
# FEB   4113.0    21.805325   35.909488     0.0     0.600     6.7    26.80
# MAR   4110.0    27.359197   46.959424     0.0     1.000     7.8    31.30
# APR   4112.0    43.127432   67.831168     0.0     3.000    15.7    49.95
# MAY   4113.0    85.745417  123.234904     0.0     8.600    36.6    97.20
# JUN   4111.0   230.234444  234.710758     0.4    70.350   138.7   305.15
# JUL   4109.0   347.214334  269.539667     0.0   175.600   284.8   418.40
# AUG   4112.0   290.263497  188.770477     0.0   155.975   259.4   377.80
# SEP   4110.0   197.361922  135.408345     0.1   100.525   173.9   265.80
# OCT   4109.0    95.507009   99.519134     0.0    14.600    65.2   148.40
# NOV   4105.0    39.866163   68.685410     0.0     0.700     9.5    46.10
# ...

# %%
list(data1)
# Out:
# ['SUBDIVISION',
#  'YEAR',
#  'JAN',
#  'FEB',
#  'MAR',
#  'APR',
#  'MAY',
#  'JUN',
#  'JUL',
#  'AUG',
#  'SEP',
#  'OCT',
#  'NOV',
#  'DEC']

# %%
cols = ['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']
for i in cols:
    col_mean = data1[i].mean()
    data1[i].fillna(col_mean,inplace=True)

# %%
data1.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
x = data['JAN']+data['FEB']
x
# Out:
# 0       136.3
# 1       159.8
# 2       156.7
# 3        24.1
# 4         1.3
#         ...
# 4111      7.9
# 4112     19.3
# 4113     60.6
# 4114     69.3
# 4115      2.7
# Length: 4116, dtype: float64

# %%
data1['ANNUAL'] = data1[cols].sum(axis=1)
data1['Jan-Feb'] = data1[['JAN','FEB']].sum(axis=1)
data1['Mar-May'] = data1[['MAR','APR','MAY']].sum(axis=1)
data1['Jun-Sep'] = data1[['JUN','JUL','AUG','SEP']].sum(axis=1)
data1['Oct-Dec'] = data1[['OCT','NOV','DEC']].sum(axis=1)

# %%
data1.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data1.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %% [markdown]
# __Another Way to fill, I use ffill method__

# %%
data2 = data.drop(['Jan-Feb','Mar-May','Jun-Sep','Oct-Dec','ANNUAL'],axis=1)
data2.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC
# 0  365.1  481.1  332.6  388.5  558.2   33.6
# 1  228.9  753.7  666.2  197.2  359.0  160.5
# 2  728.4  326.7  339.0  181.2  284.4  225.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1
# 4  368.7  330.5  297.0  260.7   25.4  344.7

# %%
data2.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC
# 0  365.1  481.1  332.6  388.5  558.2   33.6
# 1  228.9  753.7  666.2  197.2  359.0  160.5
# 2  728.4  326.7  339.0  181.2  284.4  225.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1
# 4  368.7  330.5  297.0  260.7   25.4  344.7

# %%
data2.isna().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# dtype: int64

# %%
data2.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
data2 = data2.fillna(method='ffill')

# %%
data2.head(50)
# Out:
#                   SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN  \
# 0   ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3  528.8  517.5
# 1   ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0  446.1  537.1
# 2   ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0  235.1  479.9
# 3   ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4  304.5  495.1
# 4   ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9  279.5  628.7
# 5   ANDAMAN & NICOBAR ISLANDS  1906   36.6    0.0    0.0    0.0  556.1  733.3
# 6   ANDAMAN & NICOBAR ISLANDS  1907  110.7    0.0  113.3   21.6  616.3  305.2
# 7   ANDAMAN & NICOBAR ISLANDS  1908   20.9   85.1    0.0   29.0  562.0  693.6
# 8   ANDAMAN & NICOBAR ISLANDS  1910   26.6   22.7  206.3   89.3  224.5  472.7
# 9   ANDAMAN & NICOBAR ISLANDS  1911    0.0    8.4    0.0  122.5  327.3  649.0
# 10  ANDAMAN & NICOBAR ISLANDS  1912  583.7    0.8    0.0   21.9  140.7  549.8
# ...

# %% [markdown]
# _This will fill the values with before year data_

# %%
data3 = data.copy()
data3.isna().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data3 = data3.drop(['ANNUAL','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec'],axis=1)

# %%
x = data3['SUBDIVISION'].unique().tolist()
for i in x:
    print(i)
    z = data3[data3['SUBDIVISION'] == i]
    print(z.isna().sum())
    print("#####################")
# Out:
# ANDAMAN & NICOBAR ISLANDS
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            2
# APR            2
# MAY            1
# JUN            2
# JUL            2
# AUG            2
# SEP            3
# OCT            2
# NOV            2
# DEC            3
# dtype: int64
# #####################
# ARUNACHAL PRADESH
# SUBDIVISION    0
# YEAR           0
# JAN            1
# FEB            1
# MAR            2
# APR            0
# MAY            0
# JUN            1
# JUL            1
# AUG            0
# SEP            0
# OCT            2
# NOV            2
# DEC            2
# dtype: int64
# #####################
# ASSAM & MEGHALAYA
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64
# #####################
# ...

# %%
null_state = ['ANDAMAN & NICOBAR ISLANDS','ARUNACHAL PRADESH','JAMMU & KASHMIR','WEST MADHYA PRADESH','COASTAL KARNATAKA','LAKSHADWEEP']
cols = ['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']
for i in null_state:
    # print(i)
    z = data3[data3['SUBDIVISION'] == i]
    for j in cols:
        col_mean = z[j].mean()
        z[j].fillna(col_mean,inplace=True)
    # print(z.isna().sum())
    # print("#####################")
    # print(data3.shape)
    # print(z.shape)
    data3.update(z)
    # combined_df = pd.concat([z, data3], ignore_index=True)
print(data3.shape)
print(data3.isna().sum())
data3.head()
# Out:
# (4116, 14)
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC
# 0  365.1  481.1  332.6  388.5  558.2   33.6
# 1  228.9  753.7  666.2  197.2  359.0  160.5
# 2  728.4  326.7  339.0  181.2  284.4  225.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1
# ...

# %%
print(data1.shape)
print(data.shape)
# Out:
# (4116, 19)
# (4116, 19)

# %%
# combined_df = pd.concat([data1, data], ignore_index=True)
# combined_df.shape

# %%
p = data[data['SUBDIVISION']=='KERALA']
p['JAN'].mean()
# Out:
# 12.246956521739131

# %%
data3['ANNUAL'] = data3[cols].sum(axis=1)
data3['Jan-Feb'] = data3[['JAN','FEB']].sum(axis=1)
data3['Mar-May'] = data3[['MAR','APR','MAY']].sum(axis=1)
data3['Jun-Sep'] = data3[['JUN','JUL','AUG','SEP']].sum(axis=1)
data3['Oct-Dec'] = data3[['OCT','NOV','DEC']].sum(axis=1)

# %%
data3.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data3.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
# data3.to_csv('RainFall_in_India(Cleaned).csv')

# %%
new_data = data3[(data3['SUBDIVISION']=='TAMIL NADU') | (data3['SUBDIVISION']=='KERALA') ]
new_data
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN    JUL    AUG  \
# 3427  TAMIL NADU  1901  24.5  39.1  21.7   36.0   74.0    41.8   49.3   67.9
# 3428  TAMIL NADU  1902  67.2   9.8  25.1   21.9   84.7    39.3   55.1  113.8
# 3429  TAMIL NADU  1903  19.3   7.8   1.7   18.2  128.5    58.5   72.6  115.0
# 3430  TAMIL NADU  1904  35.2   0.1   0.7   19.5  121.9    34.9   89.0   40.4
# 3431  TAMIL NADU  1905   6.5   7.5  17.2   64.8   83.7    49.8   39.0  101.8
# ...          ...   ...   ...   ...   ...    ...    ...     ...    ...    ...
# 3997      KERALA  2011  20.5  45.7  24.1  165.2  124.2   788.5  536.8  492.7
# 3998      KERALA  2012   7.4  11.0  21.0  171.1   95.3   430.3  362.6  501.6
# 3999      KERALA  2013   3.9  40.1  49.9   49.3  119.3  1042.7  830.2  369.7
# 4000      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4  677.8  733.9
# 4001      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6  406.0  252.2
#
# ...

# %%
list(new_data)
# Out:
# ['SUBDIVISION',
#  'YEAR',
#  'JAN',
#  'FEB',
#  'MAR',
#  'APR',
#  'MAY',
#  'JUN',
#  'JUL',
#  'AUG',
#  'SEP',
#  'OCT',
#  'NOV',
#  'DEC',
#  'ANNUAL',
#  'Jan-Feb',
#  'Mar-May',
#  'Jun-Sep',
#  'Oct-Dec']

# %%
new_data = new_data.drop(['ANNUAL','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec'],axis=1)
new_data.head()
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY   JUN   JUL    AUG  \
# 3427  TAMIL NADU  1901  24.5  39.1  21.7  36.0   74.0  41.8  49.3   67.9
# 3428  TAMIL NADU  1902  67.2   9.8  25.1  21.9   84.7  39.3  55.1  113.8
# 3429  TAMIL NADU  1903  19.3   7.8   1.7  18.2  128.5  58.5  72.6  115.0
# 3430  TAMIL NADU  1904  35.2   0.1   0.7  19.5  121.9  34.9  89.0   40.4
# 3431  TAMIL NADU  1905   6.5   7.5  17.2  64.8   83.7  49.8  39.0  101.8
#
#         SEP    OCT    NOV    DEC
# 3427  191.1  122.3  212.3   80.4
# 3428   98.6  282.2  174.9  165.8
# 3429  210.4  128.1  200.5  203.2
# 3430   85.7  163.2   23.6   49.1
# 3431   73.5  250.4  123.7    3.2

# %%
month_list = ['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']
new_data['ANNUAL'] = new_data[month_list].sum(axis=1)
new_data['J-J-A-S'] = new_data[['JUN','JUL','AUG','SEP']].sum(axis=1)
new_data['Oct-Nov-Dec'] = new_data[['OCT','NOV','DEC']].sum(axis=1)
new_data
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN    JUL    AUG  \
# 3427  TAMIL NADU  1901  24.5  39.1  21.7   36.0   74.0    41.8   49.3   67.9
# 3428  TAMIL NADU  1902  67.2   9.8  25.1   21.9   84.7    39.3   55.1  113.8
# 3429  TAMIL NADU  1903  19.3   7.8   1.7   18.2  128.5    58.5   72.6  115.0
# 3430  TAMIL NADU  1904  35.2   0.1   0.7   19.5  121.9    34.9   89.0   40.4
# 3431  TAMIL NADU  1905   6.5   7.5  17.2   64.8   83.7    49.8   39.0  101.8
# ...          ...   ...   ...   ...   ...    ...    ...     ...    ...    ...
# 3997      KERALA  2011  20.5  45.7  24.1  165.2  124.2   788.5  536.8  492.7
# 3998      KERALA  2012   7.4  11.0  21.0  171.1   95.3   430.3  362.6  501.6
# 3999      KERALA  2013   3.9  40.1  49.9   49.3  119.3  1042.7  830.2  369.7
# 4000      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4  677.8  733.9
# 4001      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6  406.0  252.2
#
# ...

# %%
annual_data = new_data.drop(['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC',],axis=1)
annual_data = annual_data.reset_index()

# %%
annual_data = annual_data.drop(['index'],axis=1)

# %%
data3['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
Final_data = data3.drop(['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC','Jan-Feb','Mar-May'],axis=1)
Final_data.head()
# Out:
#                  SUBDIVISION  YEAR  ANNUAL  Jun-Sep  Oct-Dec
# 0  ANDAMAN & NICOBAR ISLANDS  1901  3373.2   1696.3    980.3
# 1  ANDAMAN & NICOBAR ISLANDS  1902  3520.7   2185.9    716.7
# 2  ANDAMAN & NICOBAR ISLANDS  1903  2957.4   1874.0    690.6
# 3  ANDAMAN & NICOBAR ISLANDS  1904  3079.6   1977.6    571.0
# 4  ANDAMAN & NICOBAR ISLANDS  1905  2566.7   1624.9    630.8

# %%
Final_data = Final_data.rename(columns={'Jun-Sep':'J-J-A-S','Oct-Dec':'Oct-Nov-Dec'})
Final_data
# Out:
#                     SUBDIVISION  YEAR  ANNUAL  J-J-A-S  Oct-Nov-Dec
# 0     ANDAMAN & NICOBAR ISLANDS  1901  3373.2   1696.3        980.3
# 1     ANDAMAN & NICOBAR ISLANDS  1902  3520.7   2185.9        716.7
# 2     ANDAMAN & NICOBAR ISLANDS  1903  2957.4   1874.0        690.6
# 3     ANDAMAN & NICOBAR ISLANDS  1904  3079.6   1977.6        571.0
# 4     ANDAMAN & NICOBAR ISLANDS  1905  2566.7   1624.9        630.8
# ...                         ...   ...     ...      ...          ...
# 4111                LAKSHADWEEP  2011  1533.7   1013.0        316.6
# 4112                LAKSHADWEEP  2012  1405.5   1119.5        167.1
# 4113                LAKSHADWEEP  2013  1426.3   1057.0        177.6
# 4114                LAKSHADWEEP  2014  1395.0    958.5        290.5
# 4115                LAKSHADWEEP  2015  1642.9    860.9        555.4
#
# [4116 rows x 5 columns]

# %%
rain_Kerala_Raj = Final_data[(Final_data['SUBDIVISION']=='EAST RAJASTHAN') | (Final_data['SUBDIVISION']=='WEST RAJASTHAN') | (Final_data['SUBDIVISION']=='KERALA') ]
rain_Kerala_Raj
# Out:
#          SUBDIVISION  YEAR  ANNUAL  J-J-A-S  Oct-Nov-Dec
# 1817  WEST RAJASTHAN  1901   158.8    142.2          2.7
# 1818  WEST RAJASTHAN  1902   195.5    189.2          1.8
# 1819  WEST RAJASTHAN  1903   307.2    293.9          0.6
# 1820  WEST RAJASTHAN  1904   167.9    121.4         11.4
# 1821  WEST RAJASTHAN  1905   114.4    100.1          0.9
# ...              ...   ...     ...      ...          ...
# 3997          KERALA  2011  3035.3   2209.2        446.4
# 3998          KERALA  2012  2151.2   1535.6        309.8
# 3999          KERALA  2013  3255.5   2561.2        431.8
# 4000          KERALA  2014  3046.6   2164.9        502.2
# 4001          KERALA  2015  2600.7   1514.7        611.1
#
# [345 rows x 5 columns]

# %%
# rain_Kerala_Raj.to_csv('RAJ_KER_RainFall.csv')

# %%
Final_data.sample(7)
# Out:
#                              SUBDIVISION  YEAR  ANNUAL  J-J-A-S  Oct-Nov-Dec
# 2965                            VIDARBHA  2014   919.0    817.5         25.8
# 2747                          MATATHWADA  1911   612.4    561.0         42.0
# 449   SUB HIMALAYAN WEST BENGAL & SIKKIM  1913  2934.9   2287.3        211.7
# 2890                            VIDARBHA  1939   881.8    792.2         39.9
# 1046                  EAST UTTAR PRADESH  1935   919.8    856.3         14.6
# 822                            JHARKHAND  1941  1513.6   1206.6        199.4
# 806                            JHARKHAND  1925  1327.6   1111.3         71.7

# %%
# %python –version
# Out:
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).
